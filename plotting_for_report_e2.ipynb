# %%
from utils import *

# %%
# Diff DR comparisons  
dr_data = 'run_data/dropout/C2_final_dropout_rate_compatison_lr_0.05_50_epochs.json'

plot_all_models_performance_from_disk(dr_data, variable_name="Dropout Rate", enforce_axis=True)
plot_performance_comparison_from_file(dr_data, enforce_axis=False, smooth_window=4, variable_name='Dropout Rate')
display_accuracy_heatmap(dr_data)
# Out:
# hi
# <style type="text/css">
# #T_464dc_row3_col1, #T_464dc_row4_col0 {
#   background: green;
# }
# </style>
# <table id="T_464dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_464dc_level0_col0" class="col_heading level0 col0" >Average Test Loss</th>
#       <th id="T_464dc_level0_col1" class="col_heading level0 col1" >Average Test Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_464dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_464dc_row0_col0" class="data row0 col0" >2.960161</td>
#       <td id="T_464dc_row0_col1" class="data row0 col1" >0.674522</td>
#     </tr>
#     <tr>
#       <th id="T_464dc_level0_row1" class="row_heading level0 row1" >0.2</th>
#       <td id="T_464dc_row1_col0" class="data row1 col0" >1.748559</td>
#       <td id="T_464dc_row1_col1" class="data row1 col1" >0.673428</td>
#     </tr>
#     <tr>
# ...
